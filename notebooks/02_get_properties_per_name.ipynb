# %%
import os, sys
import pandas as pd
from glob import glob
import requests
from datetime import date
today = date.today()
print ( "Today's date:", today)
# Out:
# Today's date: 2023-12-05

# %%
# data loading 
path = '/Users/barradd/Documents/GitHub/machine_learning_chem_RGS/data/inital-data-19-nov-23.xlsx'
my_df = pd.read_excel(path)

# %%
def query_pubchem_by_name(name):
  """Queries the PubChem database using a molecular formula query.

  Args:
    molecular_formula: A string representing the molecular formula.

  Returns:
    A list of PubChem compound IDs of the compounds that match the molecular formula query.
  """
### this is the correct way to use the fastformula 
  url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{name}/cids/JSON"



  # Make a GET request to the URL.
  response = requests.get(url)

  # Parse the JSON response.
  json_response = response.json()

    # Check if the response is successful.
  if response.status_code == 200:
    # Parse the JSON response.
    json_response = response.json()

    # Extract the PubChem compound IDs of the compounds that match the query.
    compound_ids = []
    for compound in json_response["IdentifierList"]["CID"]:
      compound_ids.append(compound)

    # Return the list of compound IDs.
    return compound_ids
  else:
    # Return an empty list if there was an error.
    return []

# %%
import pubchempy as pcp 
from rdkit import Chem

# %%
compound_cids = {} 
for compound_raw_name in my_df['Name'] : 
    # print (compound_raw_name)
    compound_raw_name = compound_raw_name.strip()
    compound_ids  = query_pubchem_by_name(compound_raw_name)
    compound_cids[compound_raw_name] = compound_ids

# %%
name_set_1, name_set_2 = compound_cids.keys(), my_df['Name'].to_list()
for num, m in enumerate ( name_set_2) :
    for n in list (name_set_1):
        if m == n :
            print ( num ,m, n , compound_cids[m] )
# Out:
# 0 Benzenesulfonyl cyanide Benzenesulfonyl cyanide [10313279]
# 1 2-phenylethene-1,1,2-tricarbonitrile 2-phenylethene-1,1,2-tricarbonitrile [285442]
# 2 benzenesulfonyl fluoride benzenesulfonyl fluoride [67779]
# 3 benzenesulfonyl chloride benzenesulfonyl chloride [7369]
# 4 Trinitromethylbenzene Trinitromethylbenzene [12503820]
# 5 Phenyl trifluoromethyl sulfone Phenyl trifluoromethyl sulfone [555605]
# 6 (Pentafluoroethyl)phenyl sulfone (Pentafluoroethyl)phenyl sulfone [12599780]
# 7 (NE)-N-benzylidene-1,1,1-trifluoromethanesulfonamide (NE)-N-benzylidene-1,1,1-trifluoromethanesulfonamide [13678597]
# 8 ((Difluoromethyl)sulfonyl)benzene ((Difluoromethyl)sulfonyl)benzene [11816356]
# 9 Phenylmethanetricarbonitrile Phenylmethanetricarbonitrile [20304470]
# 10 Benzylidenemalononitrile Benzylidenemalononitrile [17608]
# 11 phenylsulfur trifluoride phenylsulfur trifluoride [14694018]
# 12 Phenylphosphonicdifluoride Phenylphosphonicdifluoride [595499]
# 13 Phenyltetrafluorophosphorane Phenyltetrafluorophosphorane [69584]
# 14 trifluoro(phenyl)germane trifluoro(phenyl)germane [12697884]
# 15 Phosphine, dicyanophenyl- Phosphine, dicyanophenyl- [76276]
# 16 Phenylsulfur pentafluoride Phenylsulfur pentafluoride [9942464]
# 17 nitrobenzene nitrobenzene [7416]
# 18 Phenylphosphonic dichloride Phenylphosphonic dichloride [69990]
# 19 Phenylphosphonothioic dichloride Phenylphosphonothioic dichloride [19016]
# 322 Cyclobutylbenzene Cyclobutylbenzene [138219]
# 323 (1,1-Diethylpropyl)benzene (1,1-Diethylpropyl)benzene [20136]
# 324 ethylbenzene ethylbenzene [7500]
# 325 tert-Amylbenzene tert-Amylbenzene [16295]
# 326 Trimethyl(phenoxy)silane Trimethyl(phenoxy)silane [73720]
# 327 Allyl phenyl ether Allyl phenyl ether [74458]
# 328 Diphenylamine Diphenylamine [11487]
# 329 Benzyloxytrimethylsilane Benzyloxytrimethylsilane [518982]
# 330 1-Phenyladamantane 1-Phenyladamantane [522696]
# 331 Anisole Anisole [7519]
# 332 N-Phenylhydroxylamine N-Phenylhydroxylamine [7518]
# 333 1-Phenyl-3,3-dimethyltriazene 1-Phenyl-3,3-dimethyltriazene [23654]
# 334 1-Phenylaziridine 1-Phenylaziridine [69673]
# 335 Ethoxybenzene Ethoxybenzene [7674]
# 336 1-Ethyl-3-phenylurea 1-Ethyl-3-phenylurea [12115]
# 337 Butoxybenzene Butoxybenzene [14311]
# 338 Propoxybenzene Propoxybenzene [12155]
# 339 Pentyl phenyl ether Pentyl phenyl ether [16298]
# 340 Isopropoxybenzene Isopropoxybenzene [75966]
# 341 N,N'-Diphenylacetamidine N,N'-Diphenylacetamidine [12117]
# 342 ANILINE ANILINE [6115]
# 343 Methylaniline Methylaniline [7515]
# 344 Phenylhydrazine Phenylhydrazine [7516]
# 345 Ethylaniline Ethylaniline [7670]
# 346 N-Butylaniline N-Butylaniline [14310]
# 347 Diethylaniline Diethylaniline [7061]
# 348 N,N-dimethylaniline N,N-dimethylaniline [949]
# 349 N,N-Dipropylaniline N,N-Dipropylaniline [75191]

# %%
len(name_set_1),len(name_set_2)
# Out:
# (343, 350)

# %%
def checkKey(dic, key):
     
    if key in dic:
        pass
        # print("Present, ", end =" ")
        # print("value =", dic[key])
    else:
        print(f"Not present {key}")

# %%
counter0 , counter1 = 0 , 0 
for num,name in enumerate( name_set_2) :
    checkKey(compound_cids, name)
    if len(compound_cids[name]) > 0 :
        counter1+= len(compound_cids[name])

    else :
        counter0+=1
        print (num,name ,compound_cids[name])

print (counter0 , counter1)
# Out:
# 47 1,1,1,3,3,3-hexafluoro-2-(trifluoromethyl)propan-2-yl]sulfanylbenzene []
# 83 1-fluoro-4-(1,1,2,2-tetrafluoro-2-phenylethyl)benzene []
# 167 (phenyl)sulfanylidene-lambda~5~-phosphane []
# 173 (4-Methylphenyl)(oxo)diphenyl-lambda~5~phosphane []
# 175 Chloro(phenyl)(dimethylamino)phosphine []
# 177 chloroethenyl]selanylbenzene []
# 254 diethyl(phenyl)arsane []
# 7 345

# %%
for num,name in enumerate( name_set_2) :
    checkKey(compound_cids, name)
    if len(compound_cids[name]) > 1 :
        print ( name ,len(compound_cids[name]) )
# Out:
# (Z)-Benzaldehyde oxime 3

# %%
my_properties_list = [ 
    'cid',
    'molecular_formula',
    'molecular_weight',
    'exact_mass',
    'monoisotopic_mass' ,
    'charge' ,
    'heavy_atom_count',
    'h_bond_donor_count',
    'h_bond_acceptor_count',
    'xlogp',
    'tpsa',
    'canonical_smiles',
    'complexity',
    'covalent_unit_count',
    'bonds',
    'elements',
    'iupac_name'
                      ]

# %%
import time

def get_compound_info(my_cids):
    while True:
        try:
            c = pcp.Compound.from_cid(my_cids)
            return c
        except pcp.PubChemHTTPError as e:
            if e.msg == "PUGREST.ServerBusy":
        # except urllib.error.HTTPError as e:
        #     if e.code == 503:
                print("Server busy, waiting for 10 seconds...")
                time.sleep(10)  # Wait for 10 seconds before retrying
            else:
                raise e

# %%
def get_the_rdkit_features(df_to_edit):
    mol = Chem.MolFromSmiles(df_to_edit['canonical_smiles'][0])
    try:
        df_to_edit['Num_of_Rings'] = mol.GetRingInfo().NumRings()
    except AttributeError:
        # Handle the case where mol has no attribute 'GetRingInfo'
        print("Warning: Mol has no attribute 'GetRingInfo' for molecule:", df_to_edit['canonical_smiles'][0])
        print ("Setting Num_of_Rings to 0")
        df_to_edit['Num_of_Rings'] = 0

    df_to_edit['heavy_atoms'] = mol.GetNumAtoms()
    return df_to_edit, mol

# %%
def get_the_type_of_bond(mol,my_cids):
    counter_ar, counter_single, counter_double, counter_triple = 0, 0, 0, 0

    try:
        for num, m in enumerate(mol.GetAtoms()):
            # Retrieve bond information for the current atom
            bond_type = str(mol.GetBonds()[num].GetBondType())

            # Update bond type counters
            if bond_type == "AROMATIC":
                counter_ar += 1
            elif bond_type == "SINGLE":
                counter_single += 1
            elif bond_type == "DOUBLE":
                counter_double += 1
            else:
                counter_triple += 1

    except IndexError:
        # Handle out-of-range error
        print(f"Error: Index out of range when accessing bond information, CIDS: {my_cids}")
        # exit()
        # return None

    # Create and return a DataFrame containing the bond type counts
    df_temp = pd.DataFrame([counter_ar, counter_single, counter_double, counter_triple],
                           index=['aromatic_bond', 'single_bond', 'double_bond', 'triple_bond'])
    return df_temp.T

# %%
def feature_eng(dataframe, my_cid):
    element_type = pd.get_dummies( pd.Series ( dataframe['elements'].iloc[0]) ,dtype=float ).sum()
    dataframe['all_atoms_count']= dataframe['elements'].apply( lambda x:len(x))
    dataframe['all_atoms_count_unique'] = dataframe['elements'].apply( lambda x: len ( list(dict.fromkeys(x)) ) )

    df_to_edit_2 , mol  = get_the_rdkit_features(df_to_edit=dataframe)
    df_to_edit_3 = get_the_type_of_bond(mol,my_cid)

    final_dataframe = pd.concat( [df_to_edit_2, df_to_edit_3,element_type.to_frame().T],axis=1)
    final_dataframe.drop(['bonds','elements'],axis=1 ,inplace=True)
    return final_dataframe

# %%
cids_missing = {
                "diethyl(phenyl)arsane":592868,
                "chloroethenyl]selanylbenzene":13334225,
                "Chloro(phenyl)(dimethylamino)phosphine":12929704, 
                "(4-Methylphenyl)(oxo)diphenyl-lambda~5~phosphane":12550549,
                "(phenyl)sulfanylidene-lambda~5~-phosphane":13799698,
                "1-fluoro-4-(1,1,2,2-tetrafluoro-2-phenylethyl)benzene":9993363,
                "1,1,1,3,3,3-hexafluoro-2-(trifluoromethyl)propan-2-yl]sulfanylbenzene":4171287}

# %%
all_data_frames, no_cids = [],[]
# for key,my_cids in compound_cids.items():
for key  in my_df['Name'].to_list() : 
    my_cids = compound_cids[key]
    if len (my_cids) > 0 :
        # print (key,my_cids[0] )
        c = get_compound_info(my_cids[0])
        # get the information on a dictionary 
        temp_dict = c.to_dict( properties= my_properties_list) 
        # transform the dict into pandas dataframe 
        df_to_edit = pd.DataFrame.from_dict(data=temp_dict,orient='index').T
        df_temp = feature_eng(dataframe=df_to_edit, my_cid=my_cids[0])
        df_temp["Name"]=key
        all_data_frames.append(df_temp)
    else :
        # print (key,cids_missing[key] )

        no_cids.append(key)
        c = get_compound_info(cids_missing[key])
        temp_dict = c.to_dict( properties= my_properties_list) 
      
        # transform the dict into pandas dataframe 
        df_to_edit = pd.DataFrame.from_dict(data=temp_dict,orient='index').T
        df_temp = feature_eng(dataframe=df_to_edit, my_cid=cids_missing[key])
        df_temp["Name"]=key

        all_data_frames.append(df_temp)
        # no_cids.append(df_temp)

# %%
print (f"elements with no cids {len(no_cids)} , number with info {len(all_data_frames)}")
# Out:
# elements with no cids 7 , number with info 350

# %%
no_cids
# Out:
# ['1,1,1,3,3,3-hexafluoro-2-(trifluoromethyl)propan-2-yl]sulfanylbenzene',
#  '1-fluoro-4-(1,1,2,2-tetrafluoro-2-phenylethyl)benzene',
#  '(phenyl)sulfanylidene-lambda~5~-phosphane',
#  '(4-Methylphenyl)(oxo)diphenyl-lambda~5~phosphane',
#  'Chloro(phenyl)(dimethylamino)phosphine',
#  'chloroethenyl]selanylbenzene',
#  'diethyl(phenyl)arsane']

# %%
df_pubchem = pd.concat(all_data_frames, axis=0)

# %%
counter = 0
for col in df_pubchem.columns.to_list():
    if counter > 10 :
        print ()
        counter =0 
    else :
        print (col , end=" ")
        counter+=1
# Out:
# cid molecular_formula molecular_weight exact_mass monoisotopic_mass charge heavy_atom_count h_bond_donor_count h_bond_acceptor_count xlogp tpsa
# complexity covalent_unit_count iupac_name all_atoms_count all_atoms_count_unique Num_of_Rings heavy_atoms aromatic_bond single_bond double_bond triple_bond
# H N O S Name F Cl P Ge Se Si
# B As

# %%
cid_found = df_pubchem["cid"].to_list()
cid_original = [ item[0] for key, item in compound_cids.items() if len(item) >0  ]

# %%
350 - len(cid_original)
# Out:
# 14

# %%
df_pubchem.describe()
# Out:
#        all_atoms_count  all_atoms_count_unique  Num_of_Rings  heavy_atoms  \
# count       350.000000              350.000000    350.000000   350.000000
# mean         21.568571                3.511429      1.297143    11.945714
# std           6.512024                0.842044      0.589053     3.301458
# min          12.000000                2.000000      1.000000     6.000000
# 25%          17.000000                3.000000      1.000000    10.000000
# 50%          20.000000                4.000000      1.000000    11.000000
# 75%          25.000000                4.000000      1.000000    14.000000
# max          45.000000                6.000000      5.000000    25.000000
#
#        aromatic_bond  single_bond  double_bond  triple_bond           C  \
# count     350.000000   350.000000   350.000000   350.000000  350.000000
# mean        7.257143     4.011429     0.600000     0.077143    9.437143
# std         2.722535     2.371001     0.772003     0.350673    3.138684
# min         5.000000     0.000000     0.000000     0.000000    6.000000
# 25%         6.000000     2.000000     0.000000     0.000000    7.000000
# 50%         6.000000     4.000000     0.000000     0.000000    8.000000
# 75%         6.000000     5.000000     1.000000     0.000000   11.000000
# max        21.000000    14.000000     4.000000     3.000000   25.000000
#
#                 H  ...          S          F         Cl     P   Ge   Se  \
# count  350.000000  ...  78.000000  69.000000  28.000000  37.0  6.0  5.0
# mean     9.622857  ...   1.038462   3.521739   1.678571   1.0  1.0  1.0
# std      4.367835  ...   0.193552   2.055185   0.983327   0.0  0.0  0.0
# min      5.000000  ...   1.000000   1.000000   1.000000   1.0  1.0  1.0
# 25%      6.000000  ...   1.000000   2.000000   1.000000   1.0  1.0  1.0
# 50%      9.000000  ...   1.000000   3.000000   1.000000   1.0  1.0  1.0
# 75%     12.000000  ...   1.000000   5.000000   2.000000   1.0  1.0  1.0
# max     26.000000  ...   2.000000   9.000000   5.000000   1.0  1.0  1.0
#
#               Si        Br    B   As
# count  21.000000  8.000000  2.0  4.0
# mean    1.095238  1.875000  1.0  1.0
# std     0.436436  0.991031  0.0  0.0
# min     1.000000  1.000000  1.0  1.0
# 25%     1.000000  1.000000  1.0  1.0
# 50%     1.000000  1.500000  1.0  1.0
# 75%     1.000000  3.000000  1.0  1.0
# max     3.000000  3.000000  1.0  1.0
#
# [8 rows x 22 columns]

# %%
df_pubchem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 0
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cid                     350 non-null    object
#  1   molecular_formula       350 non-null    object
#  2   molecular_weight        350 non-null    object
#  3   exact_mass              350 non-null    object
#  4   monoisotopic_mass       350 non-null    object
#  5   charge                  350 non-null    object
#  6   heavy_atom_count        350 non-null    object
#  7   h_bond_donor_count      350 non-null    object
#  8   h_bond_acceptor_count   350 non-null    object
#  9   xlogp                   312 non-null    object
#  10  tpsa                    350 non-null    object
#  11  canonical_smiles        350 non-null    object
#  12  complexity              350 non-null    object
#  13  covalent_unit_count     350 non-null    object
#  14  iupac_name              348 non-null    object
#  15  all_atoms_count         350 non-null    int64
#  16  all_atoms_count_unique  350 non-null    int64
#  17  Num_of_Rings            350 non-null    int64
#  18  heavy_atoms             350 non-null    int64
#  19  aromatic_bond           350 non-null    int64
#  20  single_bond             350 non-null    int64
#  21  double_bond             350 non-null    int64
#  22  triple_bond             350 non-null    int64
#  23  C                       350 non-null    float64
#  24  H                       350 non-null    float64
#  25  N                       111 non-null    float64
#  26  O                       160 non-null    float64
#  27  S                       78 non-null     float64
#  28  Name                    350 non-null    object
#  29  F                       69 non-null     float64
#  30  Cl                      28 non-null     float64
#  31  P                       37 non-null     float64
#  32  Ge                      6 non-null      float64
#  33  Se                      5 non-null      float64
#  34  Si                      21 non-null     float64
#  35  Br                      8 non-null      float64
#  36  B                       2 non-null      float64
#  37  As                      4 non-null      float64
# dtypes: float64(14), int64(8), object(16)
# memory usage: 106.6+ KB

# %%
my_df.columns = ['substituent', 'molecular_formula', 'Name', 'ΔVC-m', 'ΔVC -p', 'σm','σp', 'Fb', 'Rc']

# %%
df_merged = pd.merge(left=my_df,right=df_pubchem,on="Name")

# %%
df_merged.head()
# Out:
#     substituent molecular_formula_x                                  Name  \
# 0        SO2CN             C7H5NO2S               Benzenesulfonyl cyanide
# 1  C(CN)=C(CN)2             C11H5N3  2-phenylethene-1,1,2-tricarbonitrile
# 2          SO2F           C6H5FO2S               benzenesulfonyl fluoride
# 3        SO2Cl            C6H5ClO2S              benzenesulfonyl chloride
# 4      C(NO2)3             C7H5N3O6                 Trinitromethylbenzene
#
#        ΔVC-m     ΔVC -p    σm    σp    Fb    Rc       cid  ...    S    F   Cl  \
# 0  27.007403  28.300000  1.10  1.26  0.97  0.29  10313279  ...  1.0  NaN  NaN
# 1  24.873869  27.000000  0.77  0.98  0.65  0.33    285442  ...  NaN  NaN  NaN
# 2  24.270832  25.381524  0.80  0.91  0.72  0.19     67779  ...  1.0  1.0  NaN
# 3  24.246359  25.200000  1.20  1.11  1.16 -0.05      7369  ...  1.0  NaN  1.0
# 4  23.556098  25.100000  0.72  0.82  0.65  0.17  12503820  ...  NaN  NaN  NaN
#
#     P  Ge  Se  Si  Br   B  As
# 0 NaN NaN NaN NaN NaN NaN NaN
# 1 NaN NaN NaN NaN NaN NaN NaN
# 2 NaN NaN NaN NaN NaN NaN NaN
# 3 NaN NaN NaN NaN NaN NaN NaN
# 4 NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 46 columns]

# %%
df_merged.shape
# Out:
# (364, 46)

# %%
df_merged.to_excel(f"../data/pubchem_data_{today}_{len(all_data_frames)}_samples.xlsx", index=False)

# %%
df_merged.to_csv(f"../data/pubchem_data_{today}_{len(all_data_frames)}_samples.csv", index=False)

# %%
df_merged.tail()
# Out:
#      substituent molecular_formula_x                 Name     ΔVC-m  ΔVC -p  \
# 359        NHEt               C8H11N         Ethylaniline -5.497615   -11.4
# 360  NH(CH2)3CH3             C10H15N       N-Butylaniline -5.685868   -11.6
# 361       N(Et)2             C10H15N       Diethylaniline -6.313378   -11.9
# 362      N(Me)2               C8H11N  N,N-dimethylaniline -6.438880   -12.3
# 363     N(C3H7)2             C12H19N  N,N-Dipropylaniline -6.940888   -12.9
#
#        σm    σp    Fb    Rc    cid  ...   S   F  Cl   P  Ge  Se  Si  Br   B  \
# 359 -0.24 -0.61 -0.04 -0.57   7670  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 360 -0.34 -0.51 -0.21 -0.30  14310  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 361 -0.23 -0.72  0.01 -0.73   7061  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 362 -0.16 -0.83  0.15 -0.98    949  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 363 -0.26 -0.93  0.06 -0.99  75191  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
#      As
# 359 NaN
# 360 NaN
# 361 NaN
# 362 NaN
# 363 NaN
#
# [5 rows x 46 columns]

# %%
df_merged.describe()
# Out:
#             ΔVC-m      ΔVC -p          σm          σp          Fb         Rc  \
# count  364.000000  364.000000  364.000000  364.000000  364.000000  364.00000
# mean     6.623192    6.225898    0.258654    0.229588    0.277692   -0.05500
# std      7.010619    8.068139    0.250236    0.349373    0.211739    0.22673
# min     -6.940888  -12.900000   -0.340000   -0.930000   -0.350000   -0.99000
# 25%      0.714734    0.200000    0.060000    0.000000    0.120000   -0.15000
# 50%      6.017193    6.100000    0.250000    0.200000    0.280000   -0.03000
# 75%     11.892883   11.325000    0.412500    0.480000    0.400000    0.10000
# max     27.007403   28.300000    1.200000    1.260000    1.160000    0.45000
#
#        all_atoms_count  all_atoms_count_unique  Num_of_Rings  heavy_atoms  \
# count       364.000000              364.000000    364.000000   364.000000
# mean         21.662088                3.519231      1.307692    11.991758
# std           6.430694                0.837919      0.588078     3.278184
# min          12.000000                2.000000      1.000000     6.000000
# 25%          17.000000                3.000000      1.000000    10.000000
# 50%          21.000000                4.000000      1.000000    11.000000
# 75%          25.000000                4.000000      2.000000    14.000000
# max          45.000000                6.000000      5.000000    25.000000
#
#        ...          S          F         Cl     P   Ge   Se         Si  \
# count  ...  82.000000  69.000000  28.000000  39.0  6.0  5.0  23.000000
# mean   ...   1.036585   3.521739   1.678571   1.0  1.0  1.0   1.086957
# std    ...   0.188897   2.055185   0.983327   0.0  0.0  0.0   0.417029
# min    ...   1.000000   1.000000   1.000000   1.0  1.0  1.0   1.000000
# 25%    ...   1.000000   2.000000   1.000000   1.0  1.0  1.0   1.000000
# 50%    ...   1.000000   3.000000   1.000000   1.0  1.0  1.0   1.000000
# 75%    ...   1.000000   5.000000   2.000000   1.0  1.0  1.0   1.000000
# max    ...   2.000000   9.000000   5.000000   1.0  1.0  1.0   3.000000
#
#              Br    B   As
# count  8.000000  2.0  4.0
# mean   1.875000  1.0  1.0
# std    0.991031  0.0  0.0
# min    1.000000  1.0  1.0
# 25%    1.000000  1.0  1.0
# 50%    1.500000  1.0  1.0
# 75%    3.000000  1.0  1.0
# max    3.000000  1.0  1.0
#
# [8 rows x 28 columns]

# %%
list_of_names_after_merge = df_merged["Name"].to_list()

# %%
repeated_compuds = []
for name in df_merged["Name"].to_list():
    count = list_of_names_after_merge.count(name)
    if count >1 :
        print ( name, count )
        if name not in repeated_compuds:
            repeated_compuds.append(name)
# Out:
# N-Phenylbenzenesulfonamide 4
# N-Phenylbenzenesulfonamide 4
# N-Phenylbenzenesulfonamide 4
# N-Phenylbenzenesulfonamide 4
# Phenyl benzoate 4
# Phenyl benzoate 4
# Phenyl benzoate 4
# Phenyl benzoate 4
# Benzanilide 4
# Benzanilide 4
# Benzanilide 4
# Benzanilide 4
# N-Benzylideneaniline 4
# N-Benzylideneaniline 4
# N-Benzylideneaniline 4
# N-Benzylideneaniline 4
# Dimethyl Phenylphosphonate 4
# Dimethyl Phenylphosphonate 4
# Dimethyl Phenylphosphonate 4
# Dimethyl Phenylphosphonate 4
# Phenyl vinyl sulfide 4
# Phenyl vinyl sulfide 4
# Phenyl vinyl sulfide 4
# Phenyl vinyl sulfide 4
# Methoxydimethylphenylsilane 4
# Methoxydimethylphenylsilane 4
# Methoxydimethylphenylsilane 4
# Methoxydimethylphenylsilane 4

# %%
df_merged [ df_merged["Name"].isin(repeated_compuds) ]
# Out:
#     substituent molecular_formula_x                         Name      ΔVC-m  \
# 46    SO2NHC6H5          C12H11NO2S   N-Phenylbenzenesulfonamide  15.147464
# 47    SO2NHC6H5          C12H11NO2S   N-Phenylbenzenesulfonamide  15.147464
# 48    NHSO2C6H5          C12H11NO2S   N-Phenylbenzenesulfonamide   3.601280
# 49    NHSO2C6H5          C12H11NO2S   N-Phenylbenzenesulfonamide   3.601280
# 109     COOC6H5            C13H10O2              Phenyl benzoate   7.805597
# 110     COOC6H5            C13H10O2              Phenyl benzoate   7.805597
# 111     OCOC6H5            C13H10O2              Phenyl benzoate   1.091240
# 112     OCOC6H5            C13H10O2              Phenyl benzoate   1.091240
# 121    CONHC6H5            C13H11NO                  Benzanilide   8.621360
# 122    CONHC6H5            C13H11NO                  Benzanilide   8.621360
# 123    NHCOC6H5            C13H11NO                  Benzanilide   1.593248
# 124    NHCOC6H5            C13H11NO                  Benzanilide   1.593248
# 130    CH=NC6H5             C13H11N         N-Benzylideneaniline   7.491842
# 131    CH=NC6H5             C13H11N         N-Benzylideneaniline   7.491842
# 132    N=CHC6H5             C13H11N         N-Benzylideneaniline   0.275477
# 133    N=CHC6H5             C13H11N         N-Benzylideneaniline   0.275477
# 138   PO(OMe)2             C8H11O3P   Dimethyl Phenylphosphonate   7.052585
# 139   PO(OMe)2             C8H11O3P   Dimethyl Phenylphosphonate   7.052585
# 140    PO(OMe)2            C8H11O3P   Dimethyl Phenylphosphonate   6.727535
# 141    PO(OMe)2            C8H11O3P   Dimethyl Phenylphosphonate   6.727535
# 166    SCH=CH2                C8H8S         Phenyl vinyl sulfide   6.927083
# 167    SCH=CH2                C8H8S         Phenyl vinyl sulfide   6.927083
# 168    SCH =CH2               C8H8S         Phenyl vinyl sulfide   3.852284
# 169    SCH =CH2               C8H8S         Phenyl vinyl sulfide   3.852284
# 237  SiMe(OMe)2            C9H14OSi  Methoxydimethylphenylsilane   3.099272
# 238  SiMe(OMe)2            C9H14OSi  Methoxydimethylphenylsilane   3.099272
# 239  Si(Me)2OMe            C9H14OSi  Methoxydimethylphenylsilane   1.216742
# 240  Si(Me)2OMe            C9H14OSi  Methoxydimethylphenylsilane   1.216742
#
#        ΔVC -p    σm    σp    Fb    Rc     cid  ...    S   F  Cl    P  Ge  Se  \
# 46   15.80000  0.56  0.65  0.51  0.14   74296  ...  1.0 NaN NaN  NaN NaN NaN
# 47   15.80000  0.56  0.65  0.51  0.14   74296  ...  1.0 NaN NaN  NaN NaN NaN
# 48    4.80000  0.16  0.01  0.24 -0.23   74296  ...  1.0 NaN NaN  NaN NaN NaN
# 49    4.80000  0.16  0.01  0.24 -0.23   74296  ...  1.0 NaN NaN  NaN NaN NaN
# 109  10.00000  0.37  0.44  0.34  0.10    7169  ...  NaN NaN NaN  NaN NaN NaN
# 110  10.00000  0.37  0.44  0.34  0.10    7169  ...  NaN NaN NaN  NaN NaN NaN
# 111   2.30000  0.21  0.13  0.26 -0.13    7169  ...  NaN NaN NaN  NaN NaN NaN
# 112   2.30000  0.21  0.13  0.26 -0.13    7169  ...  NaN NaN NaN  NaN NaN NaN
# 121   9.30000  0.23  0.41  0.17  0.24    7168  ...  NaN NaN NaN  NaN NaN NaN
# 122   9.30000  0.23  0.41  0.17  0.24    7168  ...  NaN NaN NaN  NaN NaN NaN
# 123  -1.50000  0.02 -0.19  0.13 -0.32    7168  ...  NaN NaN NaN  NaN NaN NaN
# 124  -1.50000  0.02 -0.19  0.13 -0.32    7168  ...  NaN NaN NaN  NaN NaN NaN
# 130   9.00000  0.35  0.42  0.33  0.09   10858  ...  NaN NaN NaN  NaN NaN NaN
# 131   9.00000  0.35  0.42  0.33  0.09   10858  ...  NaN NaN NaN  NaN NaN NaN
# 132  -1.30000 -0.08 -0.55  0.14 -0.69   10858  ...  NaN NaN NaN  NaN NaN NaN
# 133  -1.30000 -0.08 -0.55  0.14 -0.69   10858  ...  NaN NaN NaN  NaN NaN NaN
# 138   8.80000  0.42  0.53  0.37  0.16   75234  ...  NaN NaN NaN  1.0 NaN NaN
# 139   8.80000  0.42  0.53  0.37  0.16   75234  ...  NaN NaN NaN  1.0 NaN NaN
# 140   8.78514  0.42  0.53  0.37  0.16   75234  ...  NaN NaN NaN  1.0 NaN NaN
# 141   8.78514  0.42  0.53  0.37  0.16   75234  ...  NaN NaN NaN  1.0 NaN NaN
# 166   7.50000  0.26  0.20  0.29 -0.09   74572  ...  1.0 NaN NaN  NaN NaN NaN
# 167   7.50000  0.26  0.20  0.29 -0.09   74572  ...  1.0 NaN NaN  NaN NaN NaN
# 168   4.10000  0.26  0.20  0.29 -0.09   74572  ...  1.0 NaN NaN  NaN NaN NaN
# 169   4.10000  0.26  0.20  0.29 -0.09   74572  ...  1.0 NaN NaN  NaN NaN NaN
# 237   2.40000  0.04  0.10  0.05  0.05  140300  ...  NaN NaN NaN  NaN NaN NaN
# 238   2.40000  0.04  0.10  0.05  0.05  140300  ...  NaN NaN NaN  NaN NaN NaN
# 239   0.90000  0.04 -0.02  0.09 -0.11  140300  ...  NaN NaN NaN  NaN NaN NaN
# 240   0.90000  0.04 -0.02  0.09 -0.11  140300  ...  NaN NaN NaN  NaN NaN NaN
#
#       Si  Br   B  As
# 46   NaN NaN NaN NaN
# 47   NaN NaN NaN NaN
# 48   NaN NaN NaN NaN
# 49   NaN NaN NaN NaN
# 109  NaN NaN NaN NaN
# 110  NaN NaN NaN NaN
# 111  NaN NaN NaN NaN
# 112  NaN NaN NaN NaN
# 121  NaN NaN NaN NaN
# 122  NaN NaN NaN NaN
# 123  NaN NaN NaN NaN
# 124  NaN NaN NaN NaN
# 130  NaN NaN NaN NaN
# 131  NaN NaN NaN NaN
# 132  NaN NaN NaN NaN
# 133  NaN NaN NaN NaN
# 138  NaN NaN NaN NaN
# 139  NaN NaN NaN NaN
# 140  NaN NaN NaN NaN
# 141  NaN NaN NaN NaN
# 166  NaN NaN NaN NaN
# 167  NaN NaN NaN NaN
# 168  NaN NaN NaN NaN
# 169  NaN NaN NaN NaN
# 237  1.0 NaN NaN NaN
# 238  1.0 NaN NaN NaN
# 239  1.0 NaN NaN NaN
# 240  1.0 NaN NaN NaN
#
# [28 rows x 46 columns]

# %%
repeated_compuds
# Out:
# ['N-Phenylbenzenesulfonamide',
#  'Phenyl benzoate',
#  'Benzanilide',
#  'N-Benzylideneaniline',
#  'Dimethyl Phenylphosphonate',
#  'Phenyl vinyl sulfide',
#  'Methoxydimethylphenylsilane']
